# %% [markdown]
# #  Unemployee Data analysis

# %%
import pandas as pd
import matplotlib.pyplot as mpanalysis

# %%
df = pd.read_csv('unemployment dataframe.csv')
df
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
df=df.set_index('Country Name')

# %% [markdown]
# # Top 10 Least unemployed

# %%
df['2021'].sort_values().head(10).plot.bar()
df['2021'].sort_values().head(10)
# Out:
# Country Name
# Qatar              0.26
# Cambodia           0.61
# Niger              0.75
# Solomon Islands    1.03
# Lao PDR            1.26
# Thailand           1.42
# Benin              1.57
# Rwanda             1.61
# Burundi            1.79
# Bahrain            1.87
# Name: 2021, dtype: float64

# %% [markdown]
# # Top 10 Most unemployed

# %%
df['2021'].sort_values(ascending=False).head(10).plot.bar()
df['2021'].sort_values(ascending=False).head(10)
# Out:
# Country Name
# South Africa                      33.56
# Djibouti                          28.39
# Eswatini                          25.76
# West Bank and Gaza                24.90
# Botswana                          24.72
# Lesotho                           24.60
# Congo, Rep.                       23.01
# Gabon                             22.26
# Namibia                           21.68
# St. Vincent and the Grenadines    21.62
# Name: 2021, dtype: float64

# %% [markdown]
# ## the most, the least

# %%
print("the most unemployee")
print(df['2021'].sort_values(ascending=False).head(1).to_string())
print("the least unemployee")
print(df['2021'].sort_values().head(1).to_string())
# Out:
# the most unemployee
# Country Name
# South Africa    33.56
# the least unemployee
# Country Name
# Qatar    0.26

# %%
df
# Out:
#                             Country Code   1991   1992   1993   1994   1995  \
# Country Name
# Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84   7.83
# Afghanistan                          AFG  10.65  10.82  10.72  10.73  11.18
# Africa Western and Central           AFW   4.42   4.53   4.55   4.54   4.53
# Angola                               AGO   4.21   4.21   4.23   4.16   4.11
# Albania                              ALB  10.31  30.01  25.26  20.84  14.61
# ...                                  ...    ...    ...    ...    ...    ...
# Samoa                                WSM   2.10   2.38   2.63   3.04   3.19
# Yemen, Rep.                          YEM   8.32   8.31   8.35   8.34   8.96
# South Africa                         ZAF  29.95  29.98  29.92  29.89  29.89
# Zambia                               ZMB  18.90  19.37  19.70  18.43  16.81
# Zimbabwe                             ZWE   4.94   4.99   4.97   4.96   5.63
#
# ...
